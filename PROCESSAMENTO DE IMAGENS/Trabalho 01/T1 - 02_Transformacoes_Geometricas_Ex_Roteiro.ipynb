# %% [markdown]
# # Universidade de Fortaleza
# Mestrado em Ciência de Dados e Inteligência Artificial
#
# Professor: Daniel Macedo
#
# Aluno: Marcus Miranda

# %% [markdown]
# ### Trabalho
# 1) Realizar as Tranformações Geometricas com a foto da Lena.
#
# 1.1 - Translação
#
# 1.2 - Escala
#
# 1.3 - Rotação
#
# 1.4 - Transformação Afim

# %% [markdown]
# ### Bibliotecas Utilizadas

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Foto a ser utilizada nas transformações Geometricas

# %%
imagem = cv2.cvtColor(cv2.imread('lena.png'), cv2.COLOR_BGR2RGB)
_, ax1 = plt.subplots(figsize=(20,10))
ax1.imshow(imagem)

# %% [markdown]
# ### Transformações Geometricas

# %% [markdown]
# Transformações Geométricas (TG) são a base de inúmeras aplicações gráficas. Podem estar em:
#
# – Programas para representar layouts de circuitos eletrônico
#
# – Programas de planejamento de cidades, onde pode-se usar movimentos de translação para colocar os símbolos que definem edifícios e árvores em seus devidos lugares, rotações para orientar corretamente esses símbolos, e alteração de escala para adequar o tamanho desses símbolos
#
# – Sistemas de software sofisticados que permitem a construção de cenas realistas.
#
# Definição: Transformação geométrica é uma aplicação bijectiva entre duas figuras geométricas, no mesmo plano ou em planos diferentes, de modo que, a partir de uma figura geométrica original se forma outra geometricamente igual ou semelhante à primeira.

# %% [markdown]
# As transformações geométricas podem ser classificadas da seguinte forma:
#
# – Geometria Euclidiana:
# • Translação
# • Rotação
# • Reflexão
#
# – Geometria Afim:
# • Variação de Tamanho (scaling – escala)
# • Cisalhamento (shearing)
#
# – Geometria Projetiva:
# • Projeção Ortogonal
# • Projeção Perspectiva

# %% [markdown]
# ## Translação

# %% [markdown]
# Na geometria euclidiana, uma translação é uma transformação geométrica que move todos os pontos de uma figura ou espaço, na mesma distância em uma determinada direção. Na geometria euclidiana, uma transformação é uma correspondência de um para um entre dois conjuntos de pontos ou uma aplicação de um plano para outro.

# %% [markdown]
# Sejam A e B pontos distintos do plano. Considere o segmento orientado AB como um
# segmento de reta AB a que foi atribuído um sentido (de A para B). Os pontos A e B são a
# origem e a extremidade do segmento orientado AB, respectivamente. Um segmento
# orientado possui comprimento, direção e sentido. Dado AB um segmento orientado, a
# translação definida por AB é a transformação geométrica T que faz corresponder a cada
# ponto P do plano, o ponto Q é a extremidade do segmento orientado PQ se, e somente se,
# os segmentos orientados AB e PQ possuem o mesmo comprimento, a mesma direção (ou
# seja, são paralelos) e o mesmo sentido.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
new_image = np.zeros_like(imagem)
dx = 100
dy = 100
M = np.float32([
                  [1, 0, dx],
                  [0, 1, dy],
                  [0, 0, 1]])  

  
for i in range(imagem.shape[0]):
    for j in range(imagem.shape[1]):
        pixel_transformado = (M @ np.array([[i],[j],[1]])).astype('int64')
        x = pixel_transformado[0]
        y = pixel_transformado[1]
        x_min = 0
        x_max = imagem.shape[0]
        y_min = 0
        y_max = imagem.shape[1]
        if (x < x_min) or  (x >= x_max):
            False
        elif (y < x_min) or  (y >= y_max):
            False
        else:
            True
            new_image[pixel_transformado[0], pixel_transformado[1]] = imagem[i, j]
                
plt.imshow(new_image)
plt.show()

# %% [markdown]
# ## Escala

# %% [markdown]
# Coordenadas são multiplicadas pelos fatores de escala. Pode-se efetuar Mudanças de Escala (ou apenas Escala) de um ponto pelo eixo x(sx), ou pelo eixo y(sy), através das multiplicações.
#
# Pode-se efetuar Mudanças de Escala (ou apenas Escala) de um ponto pelo eixo x(sx), ou pelo eixo y(sy), através das multiplicações

# %%
new_image = np.zeros_like(imagem)
sx = .5
sy = .5
M = np.float32([
                  [sx, 0, 0],
                   [0, sy, 0],
                   [0, 0, 1]])    

  
for i in range(imagem.shape[0]):
    for j in range(imagem.shape[1]):
        pixel_transformado = (M @ np.array([[i],[j],[1]])).astype('int64')
        x = pixel_transformado[0]
        y = pixel_transformado[1]
        x_min = 0
        x_max = imagem.shape[0]
        y_min = 0
        y_max = imagem.shape[1]
        if (x < x_min) or  (x >= x_max):
            False
        elif (y < x_min) or  (y >= y_max):
            False
        else:
            True
            new_image[pixel_transformado[0], pixel_transformado[1]] = imagem[i, j]
                
plt.imshow(new_image)
plt.show()

# %% [markdown]
# ## Rotação

# %% [markdown]
# Sejam A, O e A’ três pontos distintos do plano. Considere o ângulo orientado α= AÔA’,
# definido pelas semirretas AO e OA’, a que se atribui, além disso, um sentido, AO para lado
# de origem e OA’ para lado de extremidade, definido como um sentido positivo (o sentido
# anti-horário). Se α é um ângulo orientado, −α será obtido a partir de α pela inversão dos
# lados de origem e extremidade. Diz-se rotação R de centro O e ângulo α a transformação
# geométrica que faz corresponder a cada ponto A do plano, o ponto A’ = R (A) nas condições
# abaixo:
# i. Se A = O, então R (A) = A, ou seja, o ponto A coincidente a origem é fixo para a rotação R.
# ii. Se A ≠ O, o ângulo AÔA é igual a α e os segmentos OA e OA’ são congruentes.

# %% [markdown]
# Para Bairral (2010), rotação é um giro de uma forma em torno de um ponto, chamado centro
# de rotação. A amplitude do giro se mantém constante e essa amplitude denomina-se ângulo
# de rotação.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
new_image = np.zeros_like(imagem)
rangle = np.deg2rad(45)
M = np.float32([
          [np.math.cos(rangle), -np.math.sin(rangle), 0],
          [np.math.sin(rangle), np.math.cos(rangle), 0],
          [0                  , 0                  , 1]])

for i in range(imagem.shape[0]):
    for j in range(imagem.shape[1]):
        pixel_transformado = (M @ np.array([[i],[j],[1]])).astype('int64')
        x = pixel_transformado[0]
        y = pixel_transformado[1]
        x_min = 0
        x_max = imagem.shape[0]
        y_min = 0
        y_max = imagem.shape[1]
        if (x < x_min) or  (x >= x_max):
            False
        elif (y < x_min) or  (y >= y_max):
            False
        else:
            True
            new_image[pixel_transformado[0], pixel_transformado[1]] = imagem[i, j]
                
plt.imshow(new_image)
plt.show()

# %%
new_image = np.zeros_like(imagem)
center_x = imagem.shape[0]//2
center_y = imagem.shape[1]//2
rangle = np.deg2rad(45)
T1 = np.array([[1,0,-center_x],[0,1,-center_y],[0,0,1]]).astype('float32')
rotacao =  np.float32([
                  [np.math.cos(rangle), -np.math.sin(rangle), 0],
                  [np.math.sin(rangle), np.math.cos(rangle),  0],
                  [0                           ,0                            ,  1]])

T2 = np.array([[1,0,center_x],[0,1,center_y],[0,0,1]]).astype('float32')

M = T2 @ rotacao @ T1

for i in range(imagem.shape[0]):
    for j in range(imagem.shape[1]):
        pixel_transformado = (M @ np.array([[i],[j],[1]])).astype('int64')
        x = pixel_transformado[0]
        y = pixel_transformado[1]
        x_min = 0
        x_max = imagem.shape[0]
        y_min = 0
        y_max = imagem.shape[1]
        if (x < x_min) or  (x >= x_max):
            False
        elif (y < x_min) or  (y >= y_max):
            False
        else:
            True
            new_image[pixel_transformado[0], pixel_transformado[1]] = imagem[i, j]
                
plt.imshow(new_image)
plt.show()

# %% [markdown]
# ## Transformação Afim

# %% [markdown]
# A já conhecida transformação afim também pode ser utilizada para a retificação aproximada de uma imagem. Consiste em, conhecendo-se as coordenadas de, no mínimo três pontos não-colineares no sistema de coordenadas da imagem inicial e no sistema de coordenadas da imagem final, através de um ajustamento pelo método paramétrico, calcular os
# coeficientes de transformação entre ambos os sistemas.

# %%
new_image = np.zeros_like(imagem)
center_x = 50
center_y = 50
rangle = np.deg2rad(45)

M = np.float32([
                  [np.math.cos(rangle), -np.math.sin(rangle), center_x*(1-np.math.cos(rangle)) + center_y*np.math.sin(rangle)],
                  [np.math.sin(rangle), np.math.cos(rangle), center_y*(1-np.math.cos(rangle)) - center_x*np.math.sin(rangle)],
                  [0, 0, 1]]
                 )


for i in range(imagem.shape[0]):
    for j in range(imagem.shape[1]):
        pixel_transformado = (M @ np.array([[i],[j],[1]])).astype('int64')
        x = pixel_transformado[0]
        y = pixel_transformado[1]
        x_min = 0
        x_max = imagem.shape[0]
        y_min = 0
        y_max = imagem.shape[1]
        if (x < x_min) or  (x >= x_max):
            False
        elif (y < x_min) or  (y >= y_max):
            False
        else:
            True
            new_image[pixel_transformado[0], pixel_transformado[1]] = imagem[i, j]
                
plt.imshow(new_image)
plt.show()
